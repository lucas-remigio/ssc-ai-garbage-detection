# %%
from keras.utils import image_dataset_from_directory
import matplotlib.pyplot as plt
from tensorflow import keras
from keras import layers
from keras import models
import tensorflow as tf
# Out:
# 2025-06-02 16:06:43.194264: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748876803.210623   19520 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748876803.215258   19520 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1748876803.227851   19520 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748876803.227875   19520 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748876803.227877   19520 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748876803.227878   19520 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-02 16:06:43.232719: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU memory growth enabled.")
    except RuntimeError as e:
        print(e)
# Out:
# GPU memory growth enabled.

# %%
import os

# Caminho local para a pasta raiz do projeto
root_path = "./"  

# Listar diretórios no caminho raiz
print("📁 Diretórios no caminho raiz:")
print(os.listdir(root_path))

# Verificar conteúdo de um caminho específico
specific_path = os.path.join(root_path, "garbage-noaug-70-15-15")
if os.path.exists(specific_path):
    print(f"\n📁 Conteúdo de {specific_path}:")
    print(os.listdir(specific_path))
else:
    print(f"\n❌ Caminho {specific_path} não existe")

# Função para listar diretórios com profundidade
def list_dirs(path, indent=0):
    for item in os.listdir(path):
        full_path = os.path.join(path, item)
        if os.path.isdir(full_path):
            print(" " * indent + "📁 " + item)
            if indent < 4:
                list_dirs(full_path, indent + 2)
        else:
            print(" " * indent + "📄 " + item)

# Explorar estrutura de diretórios
print("\n📂 Estrutura de diretórios:")
list_dirs(root_path, 0)
# Out:
# 📁 Diretórios no caminho raiz:
# ['.DS_Store', '.git', '.gitignore', 'garbage-dataset', 'garbage-dataset-aug-87-6-6', 'garbage-noaug-70-15-15', 'garbage_classifier_early_stopping.weights.h5', 'models', 'model_checkpoint.h5', 'requirements.txt', 'SSC.ipynb', 'ssc.py', 'SSC_2_final_optimized.ipynb', 'SSC_3_4.ipynb', 'SSC_3_modelo_LeakyReLU copy.ipynb']
#
# 📁 Conteúdo de ./garbage-noaug-70-15-15:
# ['.DS_Store', 'README.dataset.txt', 'README.roboflow.txt', 'test', 'train', 'valid']
#
# 📂 Estrutura de diretórios:
# 📄 .DS_Store
# 📁 .git
#   📄 COMMIT_EDITMSG
#   📄 config
#   📄 description
#   📄 FETCH_HEAD
#   📄 HEAD
#   📁 hooks
#     📄 applypatch-msg.sample
#     📄 commit-msg.sample
#     📄 fsmonitor-watchman.sample
#     📄 post-update.sample
#     📄 pre-applypatch.sample
#     📄 pre-commit.sample
#     📄 pre-merge-commit.sample
#     📄 pre-push.sample
#     📄 pre-rebase.sample
#     📄 pre-receive.sample
#     📄 prepare-commit-msg.sample
#     📄 push-to-checkout.sample
#     📄 sendemail-validate.sample
#     📄 update.sample
#   📄 index
#   📁 info
#     📄 exclude
#   📁 logs
#     📄 HEAD
#     📁 refs
#   📁 objects
#     📁 06
#     📁 0d
#     📁 0e
#     📁 1b
#     📁 1d
#     📁 20
#     📁 25
#     📁 28
#     📁 2f
#     📁 33
#     📁 47
#     📁 5f
#     📁 62
#     📁 67
#     📁 68
#     📁 69
#     📁 6d
#     📁 73
#     📁 7b
#     📁 7f
#     📁 81
#     📁 88
#     📁 8c
#     📁 8d
#     📁 92
#     📁 96
#     📁 9b
#     📁 a2
#     📁 ab
#     📁 bb
#     📄 biological_13.jpg
#     📄 biological_130.jpg
#     📄 biological_131.jpg
#     📄 biological_132.jpg
#     📄 biological_133.jpg
#     📄 biological_134.jpg
#     📄 biological_135.jpg
#     📄 biological_136.jpg
#     📄 biological_137.jpg
#     📄 biological_138.jpg
#     📄 biological_139.jpg
#     📄 biological_14.jpg
#     📄 biological_140.jpg
#     📄 biological_141.jpg
#     📄 biological_142.jpg
#     📄 biological_143.jpg
#     📄 biological_144.jpg
#     📄 biological_145.jpg
#     📄 biological_146.jpg
#     📄 biological_147.jpg
#     📄 biological_148.jpg
#     📄 biological_149.jpg
#     📄 biological_15.jpg
#     📄 biological_150.jpg
#     📄 biological_151.jpg
#     📄 biological_152.jpg
#     📄 biological_153.jpg
#     📄 biological_154.jpg
#     📄 biological_155.jpg
#     📄 biological_156.jpg
#     📄 biological_157.jpg
#     📄 biological_158.jpg
#     📄 biological_159.jpg
#     📄 biological_16.jpg
#     📄 biological_160.jpg
#     📄 biological_161.jpg
#     📄 biological_162.jpg
#     📄 biological_163.jpg
#     📄 biological_164.jpg
#     📄 biological_165.jpg
#     📄 biological_166.jpg
#     📄 biological_167.jpg
#     📄 biological_168.jpg
#     📄 biological_169.jpg
#     📄 biological_17.jpg
#     📄 biological_170.jpg
#     📄 biological_171.jpg
#     📄 biological_172.jpg
#     📄 biological_173.jpg
#     📄 biological_174.jpg
#     📄 biological_175.jpg
#     📄 biological_176.jpg
#     📄 biological_177.jpg
#     📄 biological_178.jpg
#     📄 biological_179.jpg
#     📄 biological_18.jpg
#     📄 biological_180.jpg
#     📄 biological_181.jpg
#     📄 biological_182.jpg
#     📄 biological_183.jpg
#     📄 biological_184.jpg
#     📄 biological_185.jpg
#     📄 biological_186.jpg
#     📄 biological_187.jpg
#     📄 biological_188.jpg
#     📄 biological_189.jpg
#     📄 biological_19.jpg
#     📄 biological_190.jpg
#     📄 biological_191.jpg
#     📄 biological_192.jpg
#     📄 biological_193.jpg
#     📄 biological_194.jpg
#     📄 biological_195.jpg
#     📄 biological_196.jpg
#     📄 biological_197.jpg
#     📄 biological_198.jpg
#     📄 biological_199.jpg
#     📄 biological_2.jpg
#     📄 biological_20.jpg
#     📄 biological_200.jpg
#     📄 biological_201.jpg
#     📄 biological_202.jpg
#     📄 biological_20240626_155850.jpg
#     📄 biological_20240702_095852.jpg
#     📄 biological_20240702_095915.jpg
#     📄 biological_20241210_094427.jpg
#     📄 biological_20241210_094718.jpg
#     📄 biological_20241210_105007.jpg
#     📄 biological_20241210_113856.jpg
#     📄 biological_20241210_120630.jpg
#     📄 biological_20241210_120708.jpg
#     📄 biological_20241210_120715.jpg
#     📄 biological_20241210_120754.jpg
#     📄 biological_20241210_134059.jpg
#     📄 biological_20241210_135048.jpg
#     📄 biological_20241210_152459.jpg
#     📄 biological_203.jpg
#     📄 biological_204.jpg
#     📄 biological_205.jpg
#     📄 biological_206.jpg
#     📄 biological_207.jpg
#     📄 biological_208.jpg
#     📄 biological_209.jpg
#     📄 biological_21.jpg
#     📄 biological_210.jpg
#     📄 biological_211.jpg
#     📄 biological_212.jpg
#     📄 biological_213.jpg
#     📄 biological_214.jpg
#     📄 biological_215.jpg
#     📄 biological_216.jpg
#     📄 biological_217.jpg
#     📄 biological_218.jpg
#     📄 biological_219.jpg
#     📄 biological_22.jpg
#     📄 biological_220.jpg
#     📄 biological_221.jpg
#     📄 biological_222.jpg
#     📄 biological_223.jpg
#     📄 biological_224.jpg
#     📄 biological_225.jpg
#     📄 biological_226.jpg
#     📄 biological_227.jpg
#     📄 biological_228.jpg
#     📄 biological_229.jpg
#     📄 biological_23.jpg
#     📄 biological_230.jpg
#     📄 biological_231.jpg
#     📄 biological_232.jpg
#     📄 biological_233.jpg
#     📄 biological_234.jpg
#     📄 biological_235.jpg
#     📄 biological_236.jpg
#     📄 biological_237.jpg
#     📄 biological_238.jpg
#     📄 biological_239.jpg
#     📄 biological_24.jpg
#     📄 biological_240.jpg
#     📄 biological_241.jpg
#     📄 biological_242.jpg
#     📄 biological_243.jpg
#     📄 biological_244.jpg
#     📄 biological_245.jpg
#     📄 biological_246.jpg
#     📄 biological_247.jpg
#     📄 biological_248.jpg
#     📄 biological_249.jpg
#     📄 biological_25.jpg
#     📄 biological_250.jpg
#     📄 biological_251.jpg
#     📄 biological_252.jpg
#     📄 biological_253.jpg
#     📄 biological_254.jpg
#     📄 biological_255.jpg
#     📄 biological_256.jpg
#     📄 biological_257.jpg
#     📄 biological_258.jpg
#     📄 biological_259.jpg
#     📄 biological_26.jpg
#     📄 biological_260.jpg
#     📄 biological_261.jpg
#     📄 biological_262.jpg
#     📄 biological_263.jpg
#     📄 biological_264.jpg
#     📄 biological_265.jpg
#     📄 biological_266.jpg
#     📄 biological_267.jpg
#     📄 biological_268.jpg
#     📄 biological_269.jpg
#     📄 biological_27.jpg
#     📄 biological_270.jpg
#     📄 biological_271.jpg
#     📄 biological_272.jpg
#     📄 biological_273.jpg
#     📄 biological_274.jpg
#     📄 biological_275.jpg
#     📄 biological_276.jpg
#     📄 biological_277.jpg
#     📄 biological_278.jpg
#     📄 biological_279.jpg
#     📄 biological_28.jpg
#     📄 biological_280.jpg
#     📄 biological_281.jpg
#     📄 biological_282.jpg
#     📄 biological_283.jpg
#     📄 biological_284.jpg
#     📄 biological_285.jpg
#     📄 biological_286.jpg
#     📄 biological_287.jpg
#     📄 biological_288.jpg
#     📄 biological_289.jpg
#     📄 biological_29.jpg
#     📄 biological_290.jpg
#     📄 biological_291.jpg
#     📄 biological_292.jpg
#     📄 biological_293.jpg
#     📄 biological_294.jpg
#     📄 biological_295.jpg
#     📄 biological_296.jpg
#     📄 biological_297.jpg
#     📄 biological_298.jpg
#     📄 biological_299.jpg
#     📄 biological_3.jpg
#     📄 biological_30.jpg
#     📄 biological_300.jpg
#     📄 biological_301.jpg
#     📄 biological_302.jpg
#     📄 biological_303.jpg
#     📄 biological_304.jpg
#     📄 biological_305.jpg
#     📄 biological_306.jpg
#     📄 biological_307.jpg
#     📄 biological_308.jpg
#     📄 biological_309.jpg
#     📄 biological_31.jpg
#     📄 biological_310.jpg
#     📄 biological_311.jpg
#     📄 biological_312.jpg
#     📄 biological_313.jpg
#     📄 biological_314.jpg
#     📄 biological_315.jpg
#     📄 biological_316.jpg
#     📄 biological_317.jpg
#     📄 biological_318.jpg
#     📄 biological_319.jpg
#     📄 biological_32.jpg
#     📄 biological_320.jpg
#     📄 biological_321.jpg
#     📄 biological_322.jpg
#     📄 biological_323.jpg
#     📄 biological_324.jpg
#     📄 biological_325.jpg
#     📄 biological_326.jpg
#     📄 biological_327.jpg
#     📄 biological_328.jpg
#     📄 biological_329.jpg
#     📄 biological_33.jpg
#     📄 biological_330.jpg
#     📄 biological_331.jpg
#     📄 biological_332.jpg
#     📄 biological_333.jpg
#     📄 biological_334.jpg
#     📄 biological_335.jpg
#     📄 biological_336.jpg
#     📄 biological_337.jpg
#     📄 biological_338.jpg
#     📄 biological_339.jpg
#     📄 biological_34.jpg
#     📄 biological_340.jpg
#     📄 biological_341.jpg
#     📄 biological_342.jpg
#     📄 biological_343.jpg
#     📄 biological_344.jpg
#     📄 biological_345.jpg
#     📄 biological_346.jpg
#     📄 biological_347.jpg
#     📄 biological_348.jpg
#     📄 biological_349.jpg
#     📄 biological_35.jpg
#     📄 biological_350.jpg
#     📄 biological_351.jpg
#     📄 biological_352.jpg
#     📄 biological_353.jpg
#     📄 biological_354.jpg
#     📄 biological_355.jpg
#     📄 biological_356.jpg
#     📄 biological_357.jpg
#     📄 biological_358.jpg
#     📄 biological_359.jpg
#     📄 biological_36.jpg
#     📄 biological_360.jpg
#     📄 biological_361.jpg
#     📄 biological_362.jpg
#     📄 biological_363.jpg
#     📄 biological_364.jpg
#     📄 biological_365.jpg
#     📄 biological_366.jpg
#     📄 biological_367.jpg
#     📄 biological_368.jpg
#     📄 biological_369.jpg
#     📄 biological_37.jpg
#     📄 biological_370.jpg
#     📄 biological_371.jpg
#     📄 biological_372.jpg
#     📄 biological_373.jpg
#     📄 biological_374.jpg
#     📄 biological_375.jpg
#     📄 biological_376.jpg
#     📄 biological_377.jpg
#     📄 biological_378.jpg
#     📄 biological_379.jpg
#     📄 biological_38.jpg
#     📄 biological_380.jpg
#     📄 biological_381.jpg
#     📄 biological_382.jpg
#     📄 biological_383.jpg
#     📄 biological_384.jpg
#     📄 biological_385.jpg
#     📄 biological_386.jpg
#     📄 biological_387.jpg
#     📄 biological_388.jpg
#     📄 biological_389.jpg
#     📄 biological_39.jpg
#     📄 biological_390.jpg
#     📄 biological_391.jpg
#     📄 biological_393.jpg
#     📄 biological_394.jpg
#     📄 biological_395.jpg
#     📄 biological_396.jpg
#     📄 biological_397.jpg
#     📄 biological_398.jpg
#     📄 biological_399.jpg
#     📄 biological_4.jpg
#     📄 biological_40.jpg
#     📄 biological_400.jpg
#     📄 biological_401.jpg
#     📄 biological_402.jpg
#     📄 biological_403.jpg
#     📄 biological_404.jpg
#     📄 biological_405.jpg
#     📄 biological_406.jpg
#     📄 biological_407.jpg
#     📄 biological_408.jpg
#     📄 biological_409.jpg
#     📄 biological_41.jpg
#     📄 biological_410.jpg
#     📄 biological_411.jpg
#     📄 biological_412.jpg
#     📄 biological_413.jpg
#     📄 biological_414.jpg
#     📄 biological_415.jpg
#     📄 biological_416.jpg
#     📄 biological_417.jpg
#     📄 biological_418.jpg
#     📄 biological_419.jpg
#     📄 biological_42.jpg
#     📄 biological_420.jpg
#     📄 biological_421.jpg
#     📄 biological_422.jpg
#     📄 biological_423.jpg
#     📄 biological_424.jpg
#     📄 biological_425.jpg
#     📄 biological_426.jpg
#     📄 biological_427.jpg
#     📄 biological_428.jpg
#     📄 biological_429.jpg
#     📄 biological_43.jpg
#     📄 biological_430.jpg
#     📄 biological_431.jpg
#     📄 biological_432.jpg
#     📄 biological_433.jpg
#     📄 biological_434.jpg
#     📄 biological_435.jpg
#     📄 biological_436.jpg
#     📄 biological_437.jpg
#     📄 biological_438.jpg
#     📄 biological_439.jpg
#     📄 biological_44.jpg
#     📄 biological_440.jpg
#     📄 biological_441.jpg
#     📄 biological_442.jpg
#     📄 biological_443.jpg
#     📄 biological_444.jpg
#     📄 biological_445.jpg
#     📄 biological_446.jpg
#     📄 biological_447.jpg
#     📄 biological_448.jpg
#     📄 biological_449.jpg
#     📄 biological_45.jpg
#     📄 biological_450.jpg
#     📄 biological_451.jpg
#     📄 biological_452.jpg
#     📄 biological_453.jpg
#     📄 biological_454.jpg
#     📄 biological_455.jpg
#     📄 biological_456.jpg
#     📄 biological_457.jpg
#     📄 biological_458.jpg
#     📄 biological_459.jpg
#     📄 biological_46.jpg
#     📄 biological_460.jpg
#     📄 biological_461.jpg
#     📄 biological_462.jpg
#     📄 biological_463.jpg
#     📄 biological_464.jpg
#     📄 biological_465.jpg
#     📄 biological_466.jpg
#     📄 biological_467.jpg
#     📄 biological_468.jpg
#     📄 biological_469.jpg
#     📄 biological_47.jpg
#     📄 biological_470.jpg
#     📄 biological_471.jpg
#     📄 biological_472.jpg
#     📄 biological_473.jpg
#     📄 biological_474.jpg
#     📄 biological_475.jpg
#     📄 biological_476.jpg
#     📄 biological_477.jpg
#     📄 biological_478.jpg
#     📄 biological_479.jpg
#     📄 biological_48.jpg
#     📄 biological_480.jpg
#     📄 biological_481.jpg
#     📄 biological_482.jpg
#     📄 biological_483.jpg
#     📄 biological_484.jpg
#     📄 biological_485.jpg
#     📄 biological_486.jpg
#     📄 biological_487.jpg
#     📄 biological_488.jpg
#     📄 biological_489.jpg
#     📄 biological_49.jpg
#     📄 biological_490.jpg
#     📄 biological_491.jpg
#     📄 biological_492.jpg
#     📄 biological_493.jpg
#     📄 biological_494.jpg
#     📄 biological_495.jpg
#     📄 biological_496.jpg
#     📄 biological_497.jpg
#     📄 biological_498.jpg
#     📄 biological_499.jpg
#     📄 biological_5.jpg
#     📄 biological_50.jpg
#     📄 biological_500.jpg
#     📄 biological_501.jpg
#     📄 biological_502.jpg
#     📄 biological_503.jpg
#     📄 biological_504.jpg
#     📄 biological_505.jpg
#     📄 biological_506.jpg
#     📄 biological_507.jpg
#     📄 biological_508.jpg
#     📄 biological_509.jpg
#     📄 biological_51.jpg
#     📄 biological_510.jpg
#     📄 biological_511.jpg
#     📄 biological_512.jpg
#     📄 biological_513.jpg
#     📄 biological_514.jpg
#     📄 biological_515.jpg
#     📄 biological_516.jpg
#     📄 biological_517.jpg
#     📄 biological_518.jpg
#     📄 biological_519.jpg
#     📄 biological_52.jpg
#     📄 biological_520.jpg
#     📄 biological_521.jpg
#     📄 biological_522.jpg
#     📄 biological_523.jpg
#     📄 biological_524.jpg
#     📄 biological_525.jpg
#     📄 biological_526.jpg
#     📄 biological_527.jpg
#     📄 biological_528.jpg
#     📄 biological_529.jpg
#     📄 biological_53.jpg
#     📄 biological_530.jpg
#     📄 biological_531.jpg
#     📄 biological_532.jpg
#     📄 biological_533.jpg
#     📄 biological_534.jpg
#     📄 biological_535.jpg
#     📄 biological_536.jpg
#     📄 biological_537.jpg
#     📄 biological_538.jpg
#     📄 biological_539.jpg
#     📄 biological_54.jpg
#     📄 biological_540.jpg
#     📄 biological_541.jpg
#     📄 biological_542.jpg
#     📄 biological_543.jpg
#     📄 biological_544.jpg
#     📄 biological_545.jpg
#     📄 biological_546.jpg
#     📄 biological_547.jpg
#     📄 biological_548.jpg
#     📄 biological_549.jpg
#     📄 biological_55.jpg
#     📄 biological_550.jpg
#     📄 biological_551.jpg
#     📄 biological_552.jpg
#     📄 biological_553.jpg
#     📄 biological_554.jpg
#     📄 biological_555.jpg
#     📄 biological_556.jpg
#     📄 biological_557.jpg
#     📄 biological_558.jpg
#     📄 biological_559.jpg
#     📄 biological_56.jpg
#     📄 biological_560.jpg
#     📄 biological_561.jpg
#     📄 biological_562.jpg
#     📄 biological_563.jpg
#     📄 biological_564.jpg
#     📄 biological_565.jpg
#     📄 biological_566.jpg
#     📄 biological_567.jpg
#     📄 biological_568.jpg
#     📄 biological_569.jpg
#     📄 biological_57.jpg
#     📄 biological_570.jpg
#     📄 biological_571.jpg
#     📄 biological_572.jpg
#     📄 biological_573.jpg
#     📄 biological_574.jpg
#     📄 biological_575.jpg
#     📄 biological_576.jpg
#     📄 biological_577.jpg
#     📄 biological_578.jpg
#     📄 biological_579.jpg
#     📄 biological_58.jpg
#     📄 biological_580.jpg
#     📄 biological_581.jpg
#     📄 biological_582.jpg
#     📄 biological_583.jpg
#     📄 biological_584.jpg
#     📄 biological_585.jpg
#     📄 biological_586.jpg
#     📄 biological_587.jpg
#     📄 biological_588.jpg
#     📄 biological_589.jpg
#     📄 biological_59.jpg
#     📄 biological_590.jpg
#     📄 biological_591.jpg
#     📄 biological_592.jpg
#     📄 biological_593.jpg
#     📄 biological_594.jpg
#     📄 biological_595.jpg
#     📄 biological_596.jpg
#     📄 biological_597.jpg
#     📄 biological_598.jpg
#     📄 biological_599.jpg
#     📄 biological_6.jpg
#     📄 biological_60.jpg
#     📄 biological_600.jpg
#     📄 biological_601.jpg
#     📄 biological_602.jpg
#     📄 biological_603.jpg
#     📄 biological_604.jpg
#     📄 biological_605.jpg
#     📄 biological_606.jpg
#     📄 biological_607.jpg
#     📄 biological_608.jpg
#     📄 biological_609.jpg
#     📄 biological_61.jpg
#     📄 biological_610.jpg
#     📄 biological_611.jpg
#     📄 biological_612.jpg
#     📄 biological_613.jpg
#     📄 biological_614.jpg
#     📄 biological_615.jpg
#     📄 biological_616.jpg
#     📄 biological_617.jpg
#     📄 biological_618.jpg
#     📄 biological_619.jpg
#     📄 biological_62.jpg
#     📄 biological_620.jpg
#     📄 biological_621.jpg
#     📄 biological_622.jpg
#     📄 biological_623.jpg
#     📄 biological_624.jpg
#     📄 biological_625.jpg
#     📄 biological_626.jpg
#     📄 biological_627.jpg
#     📄 biological_628.jpg
#     📄 biological_629.jpg
#     📄 biological_63.jpg
#     📄 biological_630.jpg
#     📄 biological_631.jpg
#     📄 biological_632.jpg
#     📄 biological_633.jpg
#     📄 biological_634.jpg
#     📄 biological_635.jpg
#     📄 biological_636.jpg
#     📄 biological_637.jpg
#     📄 biological_638.jpg
#     📄 biological_639.jpg
#     📄 biological_64.jpg
#     📄 biological_641.jpg
#     📄 biological_642.jpg
#     📄 biological_643.jpg
#     📄 biological_644.jpg
#     📄 biological_645.jpg
#     📄 biological_646.jpg
#     📄 biological_647.jpg
#     📄 biological_648.jpg
#     📄 biological_649.jpg
#     📄 biological_65.jpg
#     📄 biological_650.jpg
#     📄 biological_651.jpg
#     📄 biological_652.jpg
#     📄 biological_653.jpg
#     📄 biological_654.jpg
#     📄 biological_655.jpg
#     📄 biological_656.jpg
#     📄 biological_657.jpg
#     📄 biological_658.jpg
#     📄 biological_659.jpg
#     📄 biological_66.jpg
#     📄 biological_660.jpg
#     📄 biological_661.jpg
#     📄 biological_662.jpg
#     📄 biological_663.jpg
#     📄 biological_664.jpg
#     📄 biological_665.jpg
#     📄 biological_666.jpg
#     📄 biological_667.jpg
#     📄 biological_668.jpg
#     📄 biological_669.jpg
#     📄 biological_67.jpg
#     📄 biological_670.jpg
#     📄 biological_671.jpg
#     📄 biological_672.jpg
#     📄 biological_673.jpg
#     📄 biological_674.jpg
#     📄 biological_675.jpg
#     📄 biological_676.jpg
#     📄 biological_677.jpg
#     📄 biological_678.jpg
#     📄 biological_679.jpg
#     📄 biological_68.jpg
#     📄 biological_680.jpg
#     📄 biological_681.jpg
#     📄 biological_682.jpg
#     📄 biological_683.jpg
#     📄 biological_684.jpg
#     📄 biological_685.jpg
#     📄 biological_686.jpg
#     📄 biological_687.jpg
#     📄 biological_688.jpg
#     📄 biological_689.jpg
#     📄 biological_69.jpg
#     📄 biological_690.jpg
#     📄 biological_691.jpg
#     📄 biological_692.jpg
#     📄 biological_693.jpg
#     📄 biological_694.jpg
#     📄 biological_695.jpg
#     📄 biological_696.jpg
#     📄 biological_697.jpg
#     📄 biological_698.jpg
#     📄 biological_699.jpg
#     📄 biological_7.jpg
#     📄 biological_70.jpg
#     📄 biological_700.jpg
#     📄 biological_701.jpg
#     📄 biological_702.jpg
#     📄 biological_703.jpg
#     📄 biological_704.jpg
#     📄 biological_705.jpg
#     📄 biological_706.jpg
#     📄 biological_707.jpg
#     📄 biological_708.jpg
#     📄 biological_709.jpg
#     📄 biological_71.jpg
#     📄 biological_710.jpg
#     📄 biological_711.jpg
#     📄 biological_712.jpg
#     📄 biological_713.jpg
#     📄 biological_714.jpg
#     📄 biological_715.jpg
#     📄 biological_716.jpg
#     📄 biological_717.jpg
#     📄 biological_718.jpg
#     📄 biological_719.jpg
#     📄 biological_72.jpg
#     📄 biological_720.jpg
#     📄 biological_721.jpg
#     📄 biological_722.jpg
#     📄 biological_723.jpg
#     📄 biological_724.jpg
#     📄 biological_725.jpg
#     📄 biological_726.jpg
#     📄 biological_727.jpg
#     📄 biological_728.jpg
#     📄 biological_729.jpg
#     📄 biological_73.jpg
#     📄 biological_730.jpg
#     📄 biological_731.jpg
#     📄 biological_732.jpg
#     📄 biological_733.jpg
#     📄 biological_734.jpg
#     📄 biological_735.jpg
#     📄 biological_736.jpg
#     📄 biological_737.jpg
#     📄 biological_738.jpg
#     📄 biological_739.jpg
#     📄 biological_74.jpg
#     📄 biological_740.jpg
#     📄 biological_741.jpg
#     📄 biological_742.jpg
#     📄 biological_743.jpg
#     📄 biological_744.jpg
#     📄 biological_745.jpg
#     📄 biological_746.jpg
#     📄 biological_747.jpg
#     📄 biological_748.jpg
#     📄 biological_749.jpg
#     📄 biological_75.jpg
#     📄 biological_750.jpg
#     📄 biological_751.jpg
#     📄 biological_752.jpg
#     📄 biological_753.jpg
#     📄 biological_754.jpg
#     📄 biological_755.jpg
#     📄 biological_756.jpg
#     📄 biological_757.jpg
#     📄 biological_758.jpg
#     📄 biological_759.jpg
#     📄 biological_76.jpg
#     📄 biological_760.jpg
#     📄 biological_761.jpg
#     📄 biological_762.jpg
#     📄 biological_763.jpg
#     📄 biological_764.jpg
#     📄 biological_765.jpg
#     📄 biological_766.jpg
#     📄 biological_767.jpg
#     📄 biological_768.jpg
#     📄 biological_769.jpg
#     📄 biological_77.jpg
#     📄 biological_770.jpg
#     📄 biological_771.jpg
#     📄 biological_772.jpg
#     📄 biological_773.jpg
#     📄 biological_774.jpg
#     📄 biological_775.jpg
#     📄 biological_776.jpg
#     📄 biological_777.jpg
#     📄 biological_778.jpg
#     📄 biological_779.jpg
#     📄 biological_78.jpg
#     📄 biological_780.jpg
#     📄 biological_781.jpg
#     📄 biological_782.jpg
#     📄 biological_783.jpg
#     📄 biological_784.jpg
#     📄 biological_785.jpg
#     📄 biological_786.jpg
#     📄 biological_787.jpg
#     📄 biological_788.jpg
#     📄 biological_789.jpg
#     📄 biological_79.jpg
#     📄 biological_790.jpg
#     📄 biological_791.jpg
#     📄 biological_792.jpg
#     📄 biological_793.jpg
#     📄 biological_794.jpg
#     📄 biological_795.jpg
#     📄 biological_796.jpg
#     📄 biological_797.jpg
#     📄 biological_798.jpg
#     📄 biological_799.jpg
#     📄 biological_8.jpg
#     📄 biological_80.jpg
#     📄 biological_800.jpg
#     📄 biological_801.jpg
#     📄 biological_802.jpg
#     📄 biological_803.jpg
#     📄 biological_804.jpg
#     📄 biological_805.jpg
#     📄 biological_806.jpg
#     📄 biological_807.jpg
#     📄 biological_808.jpg
#     📄 biological_809.jpg
#     📄 biological_81.jpg
#     📄 biological_810.jpg
#     📄 biological_811.jpg
#     📄 biological_812.jpg
#     📄 biological_813.jpg
#     📄 biological_814.jpg
#     📄 biological_815.jpg
#     📄 biological_816.jpg
#     📄 biological_817.jpg
#     📄 biological_818.jpg
#     📄 biological_819.jpg
#     📄 biological_82.jpg
#     📄 biological_820.jpg
#     📄 biological_821.jpg
#     📄 biological_822.jpg
#     📄 biological_823.jpg
#     📄 biological_824.jpg
#     📄 biological_825.jpg
#     📄 biological_826.jpg
#     📄 biological_827.jpg
#     📄 biological_828.jpg
#     📄 biological_829.jpg
#     📄 biological_83.jpg
#     📄 biological_830.jpg
#     📄 biological_831.jpg
#     📄 biological_832.jpg
#     📄 biological_833.jpg
#     📄 biological_834.jpg
#     📄 biological_835.jpg
#     📄 biological_836.jpg
#     📄 biological_837.jpg
#     📄 biological_838.jpg
#     📄 biological_839.jpg
#     📄 biological_84.jpg
#     📄 biological_840.jpg
#     📄 biological_841.jpg
#     📄 biological_842.jpg
#     📄 biological_843.jpg
#     📄 biological_844.jpg
#     📄 biological_845.jpg
#     📄 biological_846.jpg
#     📄 biological_847.jpg
#     📄 biological_848.jpg
#     📄 biological_849.jpg
#     📄 biological_85.jpg
#     📄 biological_850.jpg
#     📄 biological_851.jpg
#     📄 biological_852.jpg
#     📄 biological_853.jpg
#     📄 biological_854.jpg
#     📄 biological_855.jpg
#     📄 biological_856.jpg
#     📄 biological_857.jpg
#     📄 biological_858.jpg
#     📄 biological_859.jpg
#     📄 biological_86.jpg
#     📄 biological_860.jpg
#     📄 biological_861.jpg
#     📄 biological_862.jpg
#     📄 biological_863.jpg
#     📄 biological_864.jpg
#     📄 biological_865.jpg
#     📄 biological_866.jpg
#     📄 biological_867.jpg
#     📄 biological_868.jpg
#     📄 biological_869.jpg
#     📄 biological_87.jpg
#     📄 biological_870.jpg
#     📄 biological_871.jpg
#     📄 biological_872.jpg
#     📄 biological_873.jpg
#     📄 biological_874.jpg
#     📄 biological_875.jpg
#     📄 biological_876.jpg
#     📄 biological_877.jpg
#     📄 biological_878.jpg
#     📄 biological_879.jpg
#     📄 biological_88.jpg
#     📄 biological_880.jpg
#     📄 biological_881.jpg
#     📄 biological_882.jpg
#     📄 biological_883.jpg
#     📄 biological_884.jpg
#     📄 biological_885.jpg
#     📄 biological_886.jpg
#     📄 biological_887.jpg
#     📄 biological_888.jpg
#     📄 biological_889.jpg
#     📄 biological_89.jpg
#     📄 biological_890.jpg
#     📄 biological_891.jpg
#     📄 biological_892.jpg
#     📄 biological_893.jpg
#     📄 biological_894.jpg
#     📄 biological_895.jpg
#     📄 biological_896.jpg
#     📄 biological_897.jpg
#     📄 biological_898.jpg
#     📄 biological_899.jpg
#     📄 biological_9.jpg
#     📄 biological_90.jpg
#     📄 biological_900.jpg
#     📄 biological_901.jpg
#     📄 biological_902.jpg
#     📄 biological_903.jpg
#     📄 biological_904.jpg
#     📄 biological_905.jpg
#     📄 biological_906.jpg
#     📄 biological_907.jpg
#     📄 biological_908.jpg
#     📄 biological_909.jpg
#     📄 biological_91.jpg
#     📄 biological_910.jpg
#     📄 biological_911.jpg
#     📄 biological_912.jpg
#     📄 biological_913.jpg
#     📄 biological_914.jpg
#     📄 biological_915.jpg
#     📄 biological_916.jpg
#     📄 biological_917.jpg
#     📄 biological_918.jpg
#     📄 biological_919.jpg
#     📄 biological_92.jpg
#     📄 biological_920.jpg
#     📄 biological_921.jpg
#     📄 biological_922.jpg
#     📄 biological_923.jpg
#     📄 biological_924.jpg
#     📄 biological_925.jpg
#     📄 biological_926.jpg
#     📄 biological_927.jpg
#     📄 biological_928.jpg
#     📄 biological_929.jpg
#     📄 biological_93.jpg
#     📄 biological_930.jpg
#     📄 biological_931.jpg
#     📄 biological_932.jpg
#     📄 biological_933.jpg
#     📄 biological_934.jpg
#     📄 biological_935.jpg
#     📄 biological_936.jpg
#     📄 biological_937.jpg
#     📄 biological_938.jpg
#     📄 biological_939.jpg
#     📄 biological_94.jpg
#     📄 biological_940.jpg
#     📄 biological_941.jpg
#     📄 biological_942.jpg
#     📄 biological_943.jpg
#     📄 biological_944.jpg
#     📄 biological_945.jpg
#     📄 biological_946.jpg
#     📄 biological_947.jpg
#     📄 biological_948.jpg
#     📄 biological_949.jpg
#     📄 biological_95.jpg
#     📄 biological_950.jpg
#     📄 biological_951.jpg
#     📄 biological_952.jpg
#     📄 biological_953.jpg
#     📄 biological_954.jpg
#     📄 biological_955.jpg
#     📄 biological_956.jpg
#     📄 biological_957.jpg
#     📄 biological_958.jpg
#     📄 biological_959.jpg
#     📄 biological_96.jpg
#     📄 biological_960.jpg
#     📄 biological_961.jpg
#     📄 biological_962.jpg
#     📄 biological_963.jpg
#     📄 biological_964.jpg
#     📄 biological_965.jpg
#     📄 biological_966.jpg
#     📄 biological_967.jpg
#     📄 biological_968.jpg
#     📄 biological_969.jpg
#     📄 biological_97.jpg
#     📄 biological_970.jpg
#     📄 biological_971.jpg
#     📄 biological_972.jpg
#     📄 biological_973.jpg
#     📄 biological_974.jpg
#     📄 biological_975.jpg
#     📄 biological_976.jpg
#     📄 biological_977.jpg
#     📄 biological_978.jpg
#     📄 biological_979.jpg
#     📄 biological_98.jpg
#     📄 biological_980.jpg
#     📄 biological_981.jpg
#     📄 biological_982.jpg
#     📄 biological_983.jpg
#     📄 biological_984.jpg
#     📄 biological_985.jpg
#     📄 biological_99.jpg
#   📁 cardboard
#     📄 cardboard_1.jpg
#     📄 cardboard_1000.jpg
#     📄 cardboard_1002.jpg
#     📄 cardboard_1003.jpg
#     📄 cardboard_1005.jpg
#     📄 cardboard_1006.jpg
#     📄 cardboard_1009.jpg
#     📄 cardboard_101.jpg
#     📄 cardboard_1010.jpg
#     📄 cardboard_1012.jpg
#     📄 cardboard_1014.jpg
#     📄 cardboard_1015.jpg
#     📄 cardboard_1016.jpg
#     📄 cardboard_1017.jpg
#     📄 cardboard_1018.jpg
#     📄 cardboard_1019.jpg
#     📄 cardboard_102.jpg
#     📄 cardboard_1021.jpg
#     📄 cardboard_1022.jpg
#     📄 cardboard_1023.jpg
#     📄 trash_788.jpg
#     📄 trash_789.jpg
#     📄 trash_79.jpg
#     📄 trash_790.jpg
#     📄 trash_791.jpg
#     📄 trash_792.jpg
#     📄 trash_793.jpg
#     📄 trash_794.jpg
#     📄 trash_795.jpg
#     📄 trash_796.jpg
#     📄 trash_797.jpg
#     📄 trash_798.jpg
#     📄 trash_799.jpg
#     📄 trash_8.jpg
#     📄 trash_80.jpg
#     📄 trash_800.jpg
#     📄 trash_801.jpg
#     📄 trash_802.jpg
#     📄 trash_803.jpg
#     📄 trash_804.jpg
#     📄 trash_805.jpg
#     📄 trash_806.jpg
#     📄 trash_807.jpg
#     📄 trash_808.jpg
#     📄 trash_809.jpg
#     📄 trash_81.jpg
#     📄 trash_810.jpg
#     📄 trash_811.jpg
#     📄 trash_812.jpg
#     📄 trash_813.jpg
#     📄 trash_814.jpg
#     📄 trash_815.jpg
#     📄 trash_816.jpg
#     📄 trash_817.jpg
#     📄 trash_818.jpg
#     📄 trash_819.jpg
#     📄 trash_82.jpg
#     📄 trash_820.jpg
#     📄 trash_821.jpg
#     📄 trash_822.jpg
#     📄 trash_823.jpg
#     📄 trash_824.jpg
#     📄 trash_825.jpg
#     📄 trash_826.jpg
#     📄 trash_828.jpg
#     📄 trash_829.jpg
#     📄 trash_83.jpg
#     📄 trash_830.jpg
#     📄 trash_831.jpg
#     📄 trash_832.jpg
#     📄 trash_833.jpg
#     📄 trash_834.jpg
#     📄 trash_84.jpg
#     📄 trash_85.jpg
#     📄 trash_86.jpg
#     📄 trash_87.jpg
#     📄 trash_9.jpg
#     📄 trash_90.jpg
#     📄 trash_91.jpg
#     📄 trash_92.jpg
#     📄 trash_93.jpg
#     📄 trash_94.jpg
#     📄 trash_95.jpg
#     📄 trash_96.jpg
#     📄 trash_97.jpg
#     📄 trash_98.jpg
# 📁 garbage-dataset-aug-87-6-6
#   📄 README.dataset.txt
#   📄 README.roboflow.txt
#   📁 test
#     📁 battery
#     📁 biological
#     📁 cardboard
#     📁 clothes
#     📁 glass
#     📁 metal
#     📁 paper
#     📁 plastic
#     📁 shoes
#     📁 trash
#   📁 train
#     📁 battery
#     📁 biological
#     📁 cardboard
#     📁 clothes
#     📁 glass
#     📁 metal
#     📁 paper
#     📁 plastic
#     📁 shoes
#     📁 trash
#   📁 valid
#     📁 battery
#     📁 biological
#     📁 cardboard
#     📁 clothes
#     📁 glass
#     📁 metal
#     📁 paper
#     📁 plastic
#     📁 shoes
#     📁 trash
# 📁 garbage-noaug-70-15-15
#   📄 .DS_Store
#   📄 README.dataset.txt
#   📄 README.roboflow.txt
#   📁 test
#     📁 battery
#     📁 biological
#     📁 cardboard
#     📁 clothes
#     📁 glass
#     📁 metal
#     📁 paper
#     📁 plastic
#     📁 shoes
#     📁 trash
#   📁 train
#     📁 battery
#     📁 biological
#     📁 cardboard
#     📁 clothes
#     📁 glass
#     📁 metal
#     📁 paper
#     📁 plastic
#     📁 shoes
#     📁 trash
#   📁 valid
#     📁 battery
#     📁 biological
#     📁 cardboard
#     📁 clothes
#     📁 glass
#     📁 metal
#     📁 paper
#     📁 plastic
#     📁 shoes
#     📁 trash
# 📄 garbage_classifier_early_stopping.weights.h5
# 📁 models
#   📄 garbage_classifier_4.weights.h5
#   📄 garbage_classifier_early_stopping.weights.h5
#   📄 garbage_classifier_LeakyReLU.weights.h5
#   📄 garbage_classifier_model.keras
#   📄 garbage_classifier_model_4 .keras
#   📄 garbage_classifier_model_early_stopping.keras
#   📄 garbage_classifier_model_LeakyReLU .keras
#   📄 model_checkpoint.keras
# 📄 model_checkpoint.h5
# 📄 requirements.txt
# 📄 SSC.ipynb
# 📄 ssc.py
# 📄 SSC_2_final_optimized.ipynb
# 📄 SSC_3_4.ipynb
# 📄 SSC_3_modelo_LeakyReLU copy.ipynb

# %%
# Improved Metal GPU detection for Apple Silicon
try:
    # First try looking for GPU devices (newer TF versions label Metal as GPU)
    gpus = tf.config.list_physical_devices('GPU')
    if len(gpus) > 0:
        print(f"Found {len(gpus)} GPU device(s)")
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        tf.config.experimental.set_memory_growth(gpus[0], True)
        print("GPU acceleration enabled (Metal)")
    # If no GPU found, try looking specifically for MPS devices
    elif hasattr(tf.config, 'list_physical_devices') and len(tf.config.list_physical_devices('MPS')) > 0:
        mps_devices = tf.config.list_physical_devices('MPS')
        tf.config.experimental.set_visible_devices(mps_devices[0], 'MPS')
        print("MPS (Metal) device enabled")
    else:
        print("No GPU or MPS device found, using CPU")
        
    # Verify what device is being used
    print("\nDevice being used:", tf.config.get_visible_devices())
    
    # Test with a simple operation to confirm GPU usage
    with tf.device('/GPU:0'):
        a = tf.constant([[1.0, 2.0], [3.0, 4.0]])
        b = tf.constant([[5.0, 6.0], [7.0, 8.0]])
        c = tf.matmul(a, b)
        print("Matrix multiplication result:", c)
        print("GPU test successful!")
except Exception as e:
    print(f"Error setting up GPU: {e}")
    print("Falling back to CPU")
# Out:
# Found 1 GPU device(s)
# GPU acceleration enabled (Metal)
#
# Device being used: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Matrix multiplication result: tf.Tensor(
# [[19. 22.]
#  [43. 50.]], shape=(2, 2), dtype=float32)
# GPU test successful!
# I0000 00:00:1748876849.522302   19520 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4057 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2060, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
# Enable mixed precision (faster on GPU)
from tensorflow.keras.mixed_precision import set_global_policy
set_global_policy('mixed_float16')  # Use FP16 instead of FP32

# %%
train_dir = specific_path + "/train"
validation_dir = specific_path + "/valid"
test_dir = specific_path + "/test"

# Images are 640, but 224 is way faster for training
IMG_SIZE = 128
BATCH_SIZE = 64


train_dataset = image_dataset_from_directory(
    train_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE
)

validation_dataset = image_dataset_from_directory(
    validation_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE
)

test_dataset = image_dataset_from_directory(
    test_dir,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE
)

train_dataset_pref = train_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
validation_dataset_pref = validation_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
test_dataset_pref = test_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
train_dataset_pref = train_dataset_pref.take(100)
from tensorflow.data import Options
options = Options()
options.experimental_optimization.parallel_batch = False
train_dataset_pref = train_dataset_pref.with_options(options)
# Out:
# Found 13833 files belonging to 10 classes.
# Found 2965 files belonging to 10 classes.
# Found 2964 files belonging to 10 classes.

# %%
# Add this code to check class balance
import pandas as pd

class_counts = {}
for _, labels in train_dataset:
    for label in labels.numpy():
        if label not in class_counts:
            class_counts[label] = 0
        class_counts[label] += 1

df = pd.DataFrame({'class': train_dataset.class_names, 'count': [class_counts.get(i, 0) for i in range(len(train_dataset.class_names))]})
print(df)
# Out:
#         class  count
# 0     battery    666
# 1  biological    690
# 2   cardboard   1297
# 3     clothes   3730
# 4       glass   2093
# 5       metal    708
# 6       paper   1184
# 7     plastic   1382
# 8       shoes   1410
# 9       trash    673
# 2025-06-02 16:07:59.174533: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# MODELO ROBUSTO FINAL – CNN mais profunda + Dropout + Val Accuracy

import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.callbacks import EarlyStopping

IMG_SIZE = 128

# Arquitetura CNN mais profunda
inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = layers.Rescaling(1./255)(inputs)

# Bloco 1
x = layers.Conv2D(32, (3, 3), padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.MaxPooling2D((2, 2))(x)

# Bloco 2
x = layers.Conv2D(64, (3, 3), padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.MaxPooling2D((2, 2))(x)

# Bloco 3
x = layers.Conv2D(128, (3, 3), padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.MaxPooling2D((2, 2))(x)

# Bloco 4 adicional
x = layers.Conv2D(256, (3, 3), padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.MaxPooling2D((2, 2))(x)

# Fully connected
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(256)(x)
x = layers.BatchNormalization()(x)
x = layers.LeakyReLU()(x)
x = layers.Dense(128, activation='relu')(x)
outputs = layers.Dense(len(train_dataset.class_names), activation='softmax')(x)

# Modelo
model = keras.Model(inputs, outputs)

# Otimizador com LR reduzido
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0003)

model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# EarlyStopping monitorizando val_accuracy
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=4,
    restore_best_weights=True
)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     4,194,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_4 (LeakyReLU)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,620,106 (17.62 MB)
#  Trainable params: 4,618,634 (17.62 MB)
#  Non-trainable params: 1,472 (5.75 KB)

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

# %%
# Add to your training cell
import time

class TimeoutCallback(tf.keras.callbacks.Callback):
    def __init__(self, max_time_mins=2):
        super().__init__()
        self.max_time_sec = max_time_mins * 60
        self.start_time = time.time()
        
    def on_epoch_end(self, epoch, logs=None):
        elapsed = time.time() - self.start_time
        if elapsed > self.max_time_sec:
            print(f"\nReached time limit ({self.max_time_sec/3600:.1f}h). Stopping training.")
            self.model.stop_training = True

# Maximum 20 minutes of training to prevent overheating
timeout_cb = TimeoutCallback(max_time_mins=20)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy', 
    patience=5,
    restore_best_weights=True
)

checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    "models/model_checkpoint.keras", 
    save_best_only=True,
    monitor="val_accuracy"
)

# Add more callbacks for better training
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)

# Calculate class weights
total = sum(class_counts.values())
class_weight = {i: total/count for i, count in class_counts.items()}

# %%
import psutil
import subprocess
import platform

class ResourceMonitorCallback(tf.keras.callbacks.Callback):
    def __init__(self, check_interval=1):
        super().__init__()
        self.check_interval = check_interval
        self.epoch_count = 0
        self.is_mac = platform.system() == 'Darwin'
        
    def on_epoch_end(self, epoch, logs=None):
        self.epoch_count += 1
        if self.epoch_count % self.check_interval == 0:
            # Get basic info
            cpu_percent = psutil.cpu_percent(interval=0.5)
            memory = psutil.virtual_memory()
            mem_used = f"{memory.percent}% ({memory.used / 1024**3:.1f}GB)"
            
            # Temperature check - simplified
            temp = "N/A"
            if self.is_mac:
                try:
                    # Try thermal level from pmset (no sudo needed)
                    result = subprocess.run(['pmset', '-g', 'therm'], capture_output=True, text=True)
                    if "CPU_Thermal_level" in result.stdout:
                        temp = result.stdout.strip()
                except: pass
            
            # Simplified output
            print(f"\n[Epoch {epoch}] CPU: {cpu_percent}% | Memory: {mem_used}")
            print(f"Thermal: {temp}")
            print(f"GPU: {'Active' if self.is_mac else 'Unknown'}")

# Create monitor that checks every epoch
resource_monitor = ResourceMonitorCallback(check_interval=1)

# %%
# TRAINN!!!!
history = model.fit(
    train_dataset_pref,
    validation_data=validation_dataset_pref,
    epochs=20,
    class_weight=class_weight, 
    callbacks=[early_stopping, reduce_lr, checkpoint_cb, timeout_cb, resource_monitor]
)

# Save the entire model (architecture + weights + optimizer state)
model.save("models/garbage_classifier_model_LeakyReLU .keras")  
model.save_weights("models/garbage_classifier_LeakyReLU.weights.h5")
print("Model saved successfully!")
train_dataset_pref = train_dataset_pref.take(100)
from tensorflow.data import Options
options = Options()
options.experimental_optimization.parallel_batch = False
train_dataset_pref = train_dataset_pref.with_options(options)
# Out:
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1748876883.538276   19767 service.cc:152] XLA service 0x7feab001e250 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1748876883.538324   19767 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 2060, Compute Capability 7.5
# 2025-06-02 16:08:03.631977: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1748876884.918758   19767 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-06-02 16:08:06.862050: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=4,k4=1,k5=3,k6=3,k7=2} for conv %cudnn-conv-bw-input.3 = (f16[64,16,16,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[64,16,16,256]{3,2,1,0} %bitcast.10729, f16[256,3,3,128]{3,2,1,0} %bitcast.10266), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/functional_1/conv2d_3_1/convolution/Conv2DBackpropInput" source_file="/home/diogo/venvs/tf-env/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-06-02 16:08:06.865977: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=3,k4=2,k5=3,k6=3,k7=2} for conv %cudnn-conv-bw-input.3 = (f16[64,16,16,128]{3,2,1,0}, u8[0]{0}) custom-call(f16[64,16,16,256]{3,2,1,0} %bitcast.10729, f16[256,3,3,128]{3,2,1,0} %bitcast.10266), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/functional_1/conv2d_3_1/convolution/Conv2DBackpropInput" source_file="/home/diogo/venvs/tf-env/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-06-02 16:08:07.048119: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=4,k4=1,k5=3,k6=3,k7=2} for conv %cudnn-conv-bw-input.4 = (f16[64,32,32,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[64,32,32,128]{3,2,1,0} %bitcast.10667, f16[128,3,3,64]{3,2,1,0} %bitcast.10363), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/functional_1/conv2d_2_1/convolution/Conv2DBackpropInput" source_file="/home/diogo/venvs/tf-env/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-06-02 16:08:07.102099: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=3,k4=2,k5=3,k6=3,k7=2} for conv %cudnn-conv-bw-input.4 = (f16[64,32,32,64]{3,2,1,0}, u8[0]{0}) custom-call(f16[64,32,32,128]{3,2,1,0} %bitcast.10667, f16[128,3,3,64]{3,2,1,0} %bitcast.10363), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/functional_1/conv2d_2_1/convolution/Conv2DBackpropInput" source_file="/home/diogo/venvs/tf-env/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-06-02 16:08:07.269863: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=4,k4=1,k5=3,k6=3,k7=2} for conv %cudnn-conv-bw-input.5 = (f16[64,64,64,32]{3,2,1,0}, u8[0]{0}) custom-call(f16[64,64,64,64]{3,2,1,0} %bitcast.10605, f16[64,3,3,32]{3,2,1,0} %bitcast.10461), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/functional_1/conv2d_1_2/convolution/Conv2DBackpropInput" source_file="/home/diogo/venvs/tf-env/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-06-02 16:08:07.330694: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k2=3,k4=2,k5=3,k6=3,k7=2} for conv %cudnn-conv-bw-input.5 = (f16[64,64,64,32]{3,2,1,0}, u8[0]{0}) custom-call(f16[64,64,64,64]{3,2,1,0} %bitcast.10605, f16[64,3,3,32]{3,2,1,0} %bitcast.10461), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/functional_1/conv2d_1_2/convolution/Conv2DBackpropInput" source_file="/home/diogo/venvs/tf-env/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-06-02 16:08:28.774530: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng19{k2=0} for conv %cudnn-conv-bw-filter.6 = (f16[64,3,3,32]{3,2,1,0}, u8[0]{0}) custom-call(f16[64,64,64,32]{3,2,1,0} %bitcast.10603, f16[64,64,64,64]{3,2,1,0} %bitcast.10605), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv2DBackpropFilter" op_name="gradient_tape/functional_1/conv2d_1_2/convolution/Conv2DBackpropFilter" source_file="/home/diogo/venvs/tf-env/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-06-02 16:08:09.651182: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 808.334878ms
# Trying algorithm eng19{k2=0} for conv %cudnn-conv-bw-filter.6 = (f16[64,3,3,32]{3,2,1,0}, u8[0]{0}) custom-call(f16[64,64,64,32]{3,2,1,0} %bitcast.10603, f16[64,64,64,64]{3,2,1,0} %bitcast.10605), window={size=3x3 pad=1_1x1_1}, dim_labels=b01f_o01i->b01f, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv2DBackpropFilter" op_name="gradient_tape/functional_1/conv2d_1_2/convolution/Conv2DBackpropFilter" source_file="/home/diogo/venvs/tf-env/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
#   5/100 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.1130 - loss: 24.8441
# I0000 00:00:1748876896.154317   19767 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  98/100 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.3315 - loss: 19.2202
# [Epoch 0] CPU: 2.5% | Memory: 63.2% (3.9GB)
# Thermal: N/A
# GPU: Unknown
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 87ms/step - accuracy: 0.3346 - loss: 19.1442 - val_accuracy: 0.1066 - val_loss: 2.8794 - learning_rate: 3.0000e-04
# Epoch 2/20
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5838 - loss: 12.1072
# [Epoch 1] CPU: 2.3% | Memory: 64.2% (3.9GB)
# Thermal: N/A
# GPU: Unknown
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.5842 - loss: 12.0988 - val_accuracy: 0.1882 - val_loss: 2.8541 - learning_rate: 3.0000e-04
# Epoch 3/20
#  54/100 ━━━━━━━━━━━━━━━━━━━━ 18s 410ms/step - accuracy: 0.6716 - loss: 10.1861
# [Epoch 2] CPU: 3.9% | Memory: 64.8% (4.0GB)
# Thermal: N/A
# GPU: Unknown
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.6756 - loss: 9.9394 - val_accuracy: 0.2300 - val_loss: 2.5755 - learning_rate: 3.0000e-04
# Epoch 4/20
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7241 - loss: 8.0224
# [Epoch 3] CPU: 2.1% | Memory: 64.5% (4.0GB)
# Thermal: N/A
# GPU: Unknown
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.7243 - loss: 8.0215 - val_accuracy: 0.4067 - val_loss: 1.7807 - learning_rate: 3.0000e-04
# Epoch 5/20
#  54/100 ━━━━━━━━━━━━━━━━━━━━ 18s 405ms/step - accuracy: 0.7663 - loss: 6.7163
# [Epoch 4] CPU: 2.1% | Memory: 64.7% (4.0GB)
# Thermal: N/A
# GPU: Unknown
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.7727 - loss: 6.6199 - val_accuracy: 0.5727 - val_loss: 1.3031 - learning_rate: 3.0000e-04
# Epoch 6/20
#   3/100 ━━━━━━━━━━━━━━━━━━━━ 15:42 10s/step - accuracy: 0.7899 - loss: 5.9829
# [Epoch 5] CPU: 1.5% | Memory: 64.5% (4.0GB)
# Thermal: N/A
# GPU: Unknown
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.8223 - loss: 5.3888 - val_accuracy: 0.6405 - val_loss: 1.0693 - learning_rate: 3.0000e-04
# Epoch 7/20
#  76/100 ━━━━━━━━━━━━━━━━━━━━ 7s 298ms/step - accuracy: 0.8420 - loss: 4.7418
# [Epoch 6] CPU: 1.8% | Memory: 65.0% (4.0GB)
# Thermal: N/A
# GPU: Unknown
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.8452 - loss: 4.6590 - val_accuracy: 0.6563 - val_loss: 1.0826 - learning_rate: 3.0000e-04
# Epoch 8/20
#  26/100 ━━━━━━━━━━━━━━━━━━━━ 1:00 813ms/step - accuracy: 0.8613 - loss: 3.9116
# [Epoch 7] CPU: 2.9% | Memory: 64.7% (4.0GB)
# Thermal: N/A
# GPU: Unknown
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.8687 - loss: 3.7773 - val_accuracy: 0.6617 - val_loss: 1.1025 - learning_rate: 3.0000e-04
# Epoch 9/20
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8965 - loss: 3.0981
# [Epoch 8] CPU: 0.9% | Memory: 65.0% (4.0GB)
# Thermal: N/A
# GPU: Unknown
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.8964 - loss: 3.1015 - val_accuracy: 0.6830 - val_loss: 0.9704 - learning_rate: 3.0000e-04
# Epoch 10/20
#  53/100 ━━━━━━━━━━━━━━━━━━━━ 19s 411ms/step - accuracy: 0.9073 - loss: 2.8202
# [Epoch 9] CPU: 1.0% | Memory: 64.8% (4.0GB)
# Thermal: N/A
# GPU: Unknown
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.9065 - loss: 2.8343 - val_accuracy: 0.7099 - val_loss: 0.9312 - learning_rate: 3.0000e-04
# Epoch 11/20
#   2/100 ━━━━━━━━━━━━━━━━━━━━ 31:40 19s/step - accuracy: 0.9102 - loss: 2.5742
# [Epoch 10] CPU: 2.2% | Memory: 65.2% (4.0GB)
# Thermal: N/A
# GPU: Unknown
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.9149 - loss: 2.4586 - val_accuracy: 0.7251 - val_loss: 0.9075 - learning_rate: 3.0000e-04
# Epoch 12/20
#  77/100 ━━━━━━━━━━━━━━━━━━━━ 6s 294ms/step - accuracy: 0.9347 - loss: 2.0071
# [Epoch 11] CPU: 2.6% | Memory: 65.3% (4.0GB)
# Thermal: N/A
# GPU: Unknown
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9328 - loss: 2.0344 - val_accuracy: 0.7069 - val_loss: 0.9645 - learning_rate: 3.0000e-04
# Epoch 13/20
#  44/100 ━━━━━━━━━━━━━━━━━━━━ 27s 490ms/step - accuracy: 0.9370 - loss: 1.9621
# [Epoch 12] CPU: 0.9% | Memory: 65.2% (4.0GB)
# Thermal: N/A
# GPU: Unknown
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9372 - loss: 1.9300 - val_accuracy: 0.7069 - val_loss: 0.9624 - learning_rate: 3.0000e-04
# Epoch 14/20
#  11/100 ━━━━━━━━━━━━━━━━━━━━ 2:55 2s/step - accuracy: 0.9540 - loss: 1.7332
# [Epoch 13] CPU: 2.0% | Memory: 65.2% (4.0GB)
# Thermal: N/A
# GPU: Unknown
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9461 - loss: 1.6618 - val_accuracy: 0.6799 - val_loss: 1.1579 - learning_rate: 3.0000e-04
# Epoch 15/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9521 - loss: 1.4347
# [Epoch 14] CPU: 1.8% | Memory: 64.9% (4.0GB)
# Thermal: N/A
# GPU: Unknown
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.9522 - loss: 1.4328 - val_accuracy: 0.7686 - val_loss: 0.8004 - learning_rate: 6.0000e-05
# Epoch 16/20
#  54/100 ━━━━━━━━━━━━━━━━━━━━ 18s 405ms/step - accuracy: 0.9737 - loss: 0.9615
# [Epoch 15] CPU: 2.0% | Memory: 64.9% (4.0GB)
# Thermal: N/A
# GPU: Unknown
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9739 - loss: 0.9326 - val_accuracy: 0.7666 - val_loss: 0.7941 - learning_rate: 6.0000e-05
# Epoch 17/20
#  22/100 ━━━━━━━━━━━━━━━━━━━━ 1:14 961ms/step - accuracy: 0.9792 - loss: 0.9497
# [Epoch 16] CPU: 1.6% | Memory: 64.9% (4.0GB)
# Thermal: N/A
# GPU: Unknown
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9804 - loss: 0.8133 - val_accuracy: 0.7686 - val_loss: 0.8094 - learning_rate: 6.0000e-05
# Epoch 18/20
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9750 - loss: 0.8167
# [Epoch 17] CPU: 2.0% | Memory: 64.9% (4.0GB)
# Thermal: N/A
# GPU: Unknown
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9750 - loss: 0.8169 - val_accuracy: 0.7663 - val_loss: 0.8032 - learning_rate: 6.0000e-05
# Epoch 19/20
#  81/100 ━━━━━━━━━━━━━━━━━━━━ 5s 282ms/step - accuracy: 0.9779 - loss: 0.7487
# [Epoch 18] CPU: 2.2% | Memory: 65.2% (4.0GB)
# Thermal: N/A
# GPU: Unknown
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.9782 - loss: 0.7412 - val_accuracy: 0.7710 - val_loss: 0.7934 - learning_rate: 6.0000e-05
# Epoch 20/20
#  29/100 ━━━━━━━━━━━━━━━━━━━━ 51s 731ms/step - accuracy: 0.9795 - loss: 0.7565
# [Epoch 19] CPU: 1.3% | Memory: 65.1% (4.0GB)
# Thermal: N/A
# GPU: Unknown
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 236ms/step - accuracy: 0.9822 - loss: 0.7060 - val_accuracy: 0.7723 - val_loss: 0.7950 - learning_rate: 6.0000e-05
# Model saved successfully!

# %%
# Corrected plotting code for newer TensorFlow versions
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(accuracy) + 1)

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, accuracy, 'bo-', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'ro-', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'bo-', label='Training loss')
plt.plot(epochs, val_loss, 'ro-', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Evaluate on test dataset
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.4f}")
print(f"Test loss: {test_loss:.4f}")

# Visualize some predictions
import numpy as np

# Get class names from your dataset
class_names = train_dataset.class_names
print("Classes:", class_names)

# Function to show predictions for a batch of images
plt.figure(figsize=(12, 12))
for images, labels in test_dataset.take(1):
    predictions = model.predict(images)
    pred_classes = np.argmax(predictions, axis=1)
    
    for i in range(24):
        plt.subplot(6, 4, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        correct = labels[i] == pred_classes[i]
        color = "green" if correct else "red"
        
        plt.title(f"True: {class_names[labels[i]]}\nPred: {class_names[pred_classes[i]]}", 
                 color=color)
        plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.7650 - loss: 0.8040
# Test accuracy: 0.7702
# Test loss: 0.7953
# Classes: ['battery', 'biological', 'cardboard', 'clothes', 'glass', 'metal', 'paper', 'plastic', 'shoes', 'trash']
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# 2025-06-02 16:10:58.865881: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
